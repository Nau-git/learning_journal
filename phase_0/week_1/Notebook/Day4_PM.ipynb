# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('../Dataset/Student_Marks.csv') # .. = keluar 1 tingkat
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
pd.read_csv('../Dataset/ref.csv')
# Out:
#   ch1;ch2;ch3
# 0    10;1;100
# 1    20;2;200
# 2    30;3;300
# 3    40;4;400
# 4    50;5;500

# %%
pd.read_csv('../Dataset/ref.csv', sep=';')
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
pd.read_csv('../Dataset/ref.csv', delimiter=';')
# Out:
#    ch1  ch2  ch3
# 0   10    1  100
# 1   20    2  200
# 2   30    3  300
# 3   40    4  400
# 4   50    5  500

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.shape  # ada 126314 baris dan 23 kolom
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
pd.set_option("display.precision", 2)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# # Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# Dtype object makan memory/size yg gede. Lebih baik di-convert

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df.describe().T
# Out:
#                 count      mean       std      min       25%       50%  \
# gameorder    126314.0  31579.00  18231.93     1.00  15790.00  31579.00
# _iscopy      126314.0      0.50      0.50     0.00      0.00      0.50
# year_id      126314.0   1988.20     17.58  1947.00   1975.00   1990.00
# seasongame   126314.0     43.53     25.38     1.00     22.00     43.00
# is_playoffs  126314.0      0.06      0.24     0.00      0.00      0.00
# pts          126314.0    102.73     14.81     0.00     93.00    103.00
# elo_i        126314.0   1495.24    112.14  1091.64   1417.24   1500.95
# elo_n        126314.0   1495.24    112.46  1085.77   1416.99   1500.95
# win_equiv    126314.0     41.71     10.63    10.15     34.10     42.11
# opp_pts      126314.0    102.73     14.81     0.00     93.00    103.00
# opp_elo_i    126314.0   1495.24    112.14  1091.64   1417.24   1500.95
# opp_elo_n    126314.0   1495.24    112.46  1085.77   1416.99   1500.95
# ...

# %% [markdown]
# # *Data Exploration*

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0    1306.72             H           L      0.64
# 1  Huskies       66     1300.0    1293.28             A           W      0.36
#
#   notes
# 0   NaN
# 1   NaN

# %%
df['game_result']  # gak masukin ke list
# Out:
# 0         L
# 1         W
# 2         W
# 3         L
# 4         L
#          ..
# 126309    L
# 126310    W
# 126311    L
# 126312    L
# 126313    W
# Name: game_result, Length: 126314, dtype: object

# %%
df[['game_result', 'pts']] #dimasukin ke list. notice jumlah bracketnya
# Out:
#        game_result  pts
# 0                L   66
# 1                W   68
# 2                W   63
# 3                L   47
# 4                L   33
# ...            ...  ...
# 126309           L   82
# 126310           W  104
# 126311           L   91
# 126312           L   97
# 126313           W  105
#
# [126314 rows x 2 columns]

# %%
df['game_result'].unique() #cek unique value di kolom game_result
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts() #jumlah frekuensi unique values di kolom game_result
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.0  1309.65      42.01    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# 1  Huskies       66    1300.00    1293.28             A           W      0.36
# 2   Knicks       47    1306.72    1297.07             H           W      0.63
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df.sort_values(by='pts', ascending=False).head(5)
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 50094      25048  198312130DEN   NBA        1     1984  12/13/1983
# 50095      25048  198312130DEN   NBA        0     1984  12/13/1983
# 21416      10709  197004120INA   ABA        0     1970   4/12/1970
# 32881      16441  197502140SDA   ABA        0     1975   2/14/1975
# 8974        4488  195902270BOS   NBA        0     1959   2/27/1959
#
#        seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 50094          23            0     DET  Pistons  186  1491.89  1499.02
# 50095          23            0     DEN  Nuggets  184  1512.70  1505.56
# 21416          82            0     INA   Pacers  177  1432.55  1441.10
# 32881          59            0     SDA    Sails  176  1372.69  1390.94
# 8974           66            0     BOS  Celtics  173  1671.07  1678.06
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %% [markdown]
# #### Accessing elements, slicing

# %% [markdown]
# kalo pake .loc [row, column]

# %%
df.loc[2:7, 'fran_id']  # selecting row 2 to 7 and only show fran_id row
# Out:
# 2           Stags
# 3          Knicks
# 4         Falcons
# 5        Capitols
# 6         Celtics
# 7    Steamrollers
# Name: fran_id, dtype: object

# %%
df.loc[df['fran_id']=='Knicks',:]  # selecting only data with fran_id = Knicks and show all the rows
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126025      63013  201504080NYK   NBA        0     2015    4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015   4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015   4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015   4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 1                1            0     NYK  Knicks   68  1300.00  1306.72
# ...

# %%
df.loc[df['fran_id']=='Knicks',['year_id', 'pts', 'opp_id', 'opp_pts']] # selecting data with fran_id = Knicks and only show couple of rows (year_id, pts, opp_id, opp_pts)
# Out:
#         year_id  pts opp_id  opp_pts
# 1          1947   68    TRH       66
# 3          1947   47    CHS       63
# 23         1947   68    STB       63
# 37         1947   68    CHS       78
# 54         1947   64    PIT       62
# ...         ...  ...    ...      ...
# 126025     2015   86    IND      102
# 126056     2015   91    MIL       99
# 126072     2015   80    ORL       79
# 126094     2015  112    ATL      108
# 126147     2015   90    DET      112
#
# [5769 rows x 4 columns]

# %%
df.loc[df['fran_id']=='Lakers', 'team_id'].value_counts() # there are 2 data with fran_id Lakers: LAL and MNL. LAL has 5078 games while MNL has 946 games
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %% [markdown]
# #### **Query**

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df[df['year_id'] > 2010]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
# year_id > 2010
# fran_id == Warriors
# pts > 100
# game_result == W

df[
    (df['year_id']>2010) &
    (df['fran_id']== "Warriors") &
    (df['pts']>100) &
    (df['game_result']== 'W')

]         # ini 1 query
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# 113700      56851  201010290GSW   NBA        0     2011  10/29/2010
# 113767      56884  201011030GSW   NBA        0     2011   11/3/2010
# 113853      56927  201011080TOR   NBA        1     2011   11/8/2010
# 113874      56938  201011100NYK   NBA        1     2011  11/10/2010
# ...           ...           ...   ...      ...      ...         ...
# 126301      63151  201505270GSW   NBA        0     2015   5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015    6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 113668           1            0     GSW  Warriors  132  1432.78  1438.42
# ...

# %%
# bukan query?
df[
    (df['year_id']>2010) &
    (df['fran_id']== "Warriors") &
    (df['pts']>100) &
    (df['game_result']== 'W')
][['year_id', 'fran_id', 'pts']] # cuma nampilin beberapa kolom
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113853     2011  Warriors  109
# 113874     2011  Warriors  122
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [193 rows x 3 columns]

# %%
# penulisan dibalik. Specify column dulu, baru query
df[['year_id', 'fran_id', 'pts']] [
    (df['year_id']>2010) &
    (df['fran_id']== "Warriors") &
    (df['pts']>100) &
    (df['game_result']== 'W')
]
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113853     2011  Warriors  109
# 113874     2011  Warriors  122
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [193 rows x 3 columns]

# %%
# alternatif penulisan query

# year_id > 2010
# fran_id == Warriors
# pts > 100
# game_result == W

df.query('year_id > 2010 & fran_id == "Warriors" & pts > 100 & game_result == "W"')  # ini 1 query
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# 113700      56851  201010290GSW   NBA        0     2011  10/29/2010
# 113767      56884  201011030GSW   NBA        0     2011   11/3/2010
# 113853      56927  201011080TOR   NBA        1     2011   11/8/2010
# 113874      56938  201011100NYK   NBA        1     2011  11/10/2010
# ...           ...           ...   ...      ...      ...         ...
# 126301      63151  201505270GSW   NBA        0     2015   5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015    6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 113668           1            0     GSW  Warriors  132  1432.78  1438.42
# ...

# %%
# bisa juga pilih kolom yg mau ditampilin
df.query('year_id > 2010 & fran_id == "Warriors" & pts > 100 & game_result == "W"')[['year_id', 'fran_id', 'pts']]
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113853     2011  Warriors  109
# 113874     2011  Warriors  122
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [193 rows x 3 columns]

# %%
# bukan query
df[
    (df['year_id']>2010) &
    (df['fran_id']== "Warriors") &
    (df['pts']>100) &
    (df['game_result']== 'W')
][['year_id', 'fran_id', 'pts']]
# Out:
#         year_id   fran_id  pts
# 113668     2011  Warriors  132
# 113700     2011  Warriors  109
# 113767     2011  Warriors  115
# 113853     2011  Warriors  109
# 113874     2011  Warriors  122
# ...         ...       ...  ...
# 126301     2015  Warriors  104
# 126303     2015  Warriors  108
# 126308     2015  Warriors  103
# 126310     2015  Warriors  104
# 126313     2015  Warriors  105
#
# [193 rows x 3 columns]

# %% [markdown]
# # Grouping n Aggregating

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.70
# Bombers          71.46
# Bucks           103.70
# Bulls           101.53
# Capitols         76.93
# Cavaliers        99.85
# Celtics         104.47
# Clippers        101.93
# Colonels        111.63
# Condors         115.45
# Denver           77.71
# Falcons          63.28
# Floridians      112.65
# Grizzlies        95.16
# Hawks           101.81
# Heat             96.63
# Hornets          94.51
# Huskies          66.58
# Ironmen          61.23
# Jazz            102.15
# Jets             74.70
# Kings           103.97
# Knicks          100.97
# Lakers          105.82
# Magic            99.43
# Mavericks       102.63
# Nets            101.76
# Nuggets         108.20
# Olympians        81.08
# Pacers          103.69
# Packers          86.01
# Pelicans         97.96
# Pistons         101.37
# Raptors          96.92
# Rebels           71.02
# Redskins         82.65
# Rockets         104.12
# Sails           109.78
# Sixers          103.81
# ...

# %%
df.groupby('game_location')['pts'].mean()  # (grouping)[value yang diingin].Aggregating
# Out:
# game_location
# A    100.86
# H    104.60
# N    104.32
# Name: pts, dtype: float64

# %% [markdown]
# cara kerjanya:
# * 1. grouping -> game_location
# * 2. aggregate -> mean pada pts

# %% [markdown]
# detailnya:

# %%
# 1. grouping
grup = df.groupby('game_location')
grup

# %%
# 2a. aggregate
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
# 2b. aggregate
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
# 2c. aggregate
grup.get_group('N')['pts'].mean()
# Out:
# 104.3157894736842

# %% [markdown]
# Bandingkan semua hasilnya. Sama semua

# %%
# chain query + groupby

df[
    (df['year_id'] > 2012) &
    (df['fran_id'] == 'Spurs') &
    (df['game_result'] == 'W')
].groupby(['year_id', 'game_location'])['pts'].mean()
# Out:
# year_id  game_location
# 2013     A                106.17
#          H                106.28
# 2014     A                108.20
#          H                108.86
# 2015     A                105.04
#          H                107.06
# Name: pts, dtype: float64

# %%
# fran dgn rata2 pts > 100

df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.70
# Bombers          71.46
# Bucks           103.70
# Bulls           101.53
# Capitols         76.93
# Cavaliers        99.85
# Celtics         104.47
# Clippers        101.93
# Colonels        111.63
# Condors         115.45
# Denver           77.71
# Falcons          63.28
# Floridians      112.65
# Grizzlies        95.16
# Hawks           101.81
# Heat             96.63
# Hornets          94.51
# Huskies          66.58
# Ironmen          61.23
# Jazz            102.15
# Jets             74.70
# Kings           103.97
# Knicks          100.97
# Lakers          105.82
# Magic            99.43
# Mavericks       102.63
# Nets            101.76
# Nuggets         108.20
# Olympians        81.08
# Pacers          103.69
# Packers          86.01
# Pelicans         97.96
# Pistons         101.37
# Raptors          96.92
# Rebels           71.02
# Redskins         82.65
# Rockets         104.12
# Sails           109.78
# Sixers          103.81
# ...

# %%
# fran dgn rata2 pts > 100

df.groupby('fran_id')['pts'].mean().sort_values(ascending=False)  # Series
# Out:
# fran_id
# Condors         115.45
# Squires         114.05
# Floridians      112.65
# Stars           112.35
# Colonels        111.63
# Spirits         110.52
# Sails           109.78
# Sounds          108.44
# Nuggets         108.20
# Suns            107.23
# Lakers          105.82
# Spurs           105.32
# Thunder         104.77
# Warriors        104.51
# Celtics         104.47
# Rockets         104.12
# Trailblazers    104.06
# Kings           103.97
# Sixers          103.81
# Bucks           103.70
# Pacers          103.69
# Wizards         103.62
# Mavericks       102.63
# Jazz            102.15
# Clippers        101.93
# Hawks           101.81
# Nets            101.76
# Bulls           101.53
# Pistons         101.37
# Knicks          100.97
# Cavaliers        99.85
# Magic            99.43
# Pelicans         97.96
# Timberwolves     97.46
# Raptors          96.92
# Heat             96.63
# Grizzlies        95.16
# Hornets          94.51
# Packers          86.01
# ...

# %%
df2 = df.groupby('fran_id')[['pts']].mean()
df2[df2['pts']>100]  # DataFrame
# Out:
#                  pts
# fran_id
# Bucks         103.70
# Bulls         101.53
# Celtics       104.47
# Clippers      101.93
# Colonels      111.63
# Condors       115.45
# Floridians    112.65
# Hawks         101.81
# Jazz          102.15
# Kings         103.97
# Knicks        100.97
# Lakers        105.82
# Mavericks     102.63
# Nets          101.76
# Nuggets       108.20
# Pacers        103.69
# Pistons       101.37
# Rockets       104.12
# Sails         109.78
# Sixers        103.81
# Sounds        108.44
# Spirits       110.52
# Spurs         105.32
# Squires       114.05
# Stars         112.35
# Suns          107.23
# Thunder       104.77
# Trailblazers  104.06
# Warriors      104.51
# Wizards       103.62

# %% [markdown]
# # Manipulating Columns
# * create new column
#
# * rename
#
# * drop

# %%
df_new = df.copy()  #bikin backup karena akan merubah data
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# Create new column
df_new['selisih_poin'] = df_new['pts'] - df_new['opp_pts']
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# Create new column
df_new['selisih_poin'] = np.abs(df_new['pts'] - df_new['opp_pts'])  # selisihnya absolut
df_new.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_n  win_equiv opp_id  opp_fran  \
# 0            0     TRH  Huskies   66  1293.28      40.29    NYK    Knicks
# 1            0     NYK   Knicks   68  1306.72      41.71    TRH   Huskies
# 2            0     CHS    Stags   63  1309.65      42.01    NYK    Knicks
# 3            0     NYK   Knicks   47  1297.07      40.69    CHS     Stags
# 4            0     DTF  Falcons   33  1279.62      38.86    WSC  Capitols
#
#    opp_pts  opp_elo_i  opp_elo_n loc result  forecast notes  selisih_poin
# ...

# %%
# rename column
df_new.rename(columns={'game_location' : 'loc',
                        'game_result': 'result'})   # perubahan tidak permanen (hanya overview)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# rename column
df_new.rename(columns={'game_location' : 'loc',
                                'game_result': 'result'}, inplace=True)   # perubahan permanen
df_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# Drop column
df_new.drop('elo_i', axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_n  win_equiv  \
# 0                1            0     TRH    Huskies   66  1293.28      40.29
# ...

# %%
# Drop column
df_new.drop(['elo_i', 'elo_n'], axis=1, inplace=True) # permanen

# %%
df_new
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %% [markdown]
# #### cari nilai di atas rata-rata

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
mean_pts = df['pts'].mean()
print(mean_pts)
df[df['pts'] > mean_pts]
# Out:
# 102.72998242475101
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 256           129  194701010CHS   NBA        1     1947   1/1/1947
# 313           157  194701140TRH   NBA        1     1947  1/14/1947
# 399           200  194702020CLR   NBA        1     1947   2/2/1947
# 416           209  194702060CHS   NBA        0     1947   2/6/1947
# 561           281  194703080CHS   NBA        0     1947   3/8/1947
# ...           ...           ...   ...      ...      ...        ...
# 126301      63151  201505270GSW   NBA        0     2015  5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015   6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# ...
