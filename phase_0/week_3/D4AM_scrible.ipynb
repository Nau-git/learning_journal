# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ecommerce_data.csv')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df['Total'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  income  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   15.30  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   22.00  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   20.34  20.34

# %%
df['income'] = df['Quantity']*df['UnitPrice']
df['date'] = df['InvoiceDate'].dt.date
daily_income = df[['date','income']].groupby('date').sum()
print('Average Income a Day for the last a year: ${}'.format(np.round(daily_income['income'].mean())))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21488/3861052990.py in <module>
#       1 df['income'] = df['Quantity']*df['UnitPrice']
# ----> 2 df['date'] = df['InvoiceDate'].dt.date
#       3 daily_income = df[['date','income']].groupby('date').sum()
#       4 print('Average Income a Day for the last a year: ${}'.format(np.round(daily_income['income'].mean())))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
t_stat,p_val = stats.ttest_1samp(df.total, 16)
print('P-value:',p_val) #The p-value divided by 2 since the output is two-sided p-value
print('t-statistics:',t_stat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21488/2836068616.py in <module>
# ----> 1 t_stat,p_val = stats.ttest_1samp(df.total, 16)
#       2 print('P-value:',p_val) #The p-value divided by 2 since the output is two-sided p-value
#       3 print('t-statistics:',t_stat)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'total'
